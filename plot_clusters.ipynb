# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %%
def do_plot(filename):

    with open(filename) as file:
        context = file.read()
        size = len(context)
        arraystr= context[1:size-1]
        arraystr = arraystr.split(',')
        cluster_0_counts = [float(item) for item in arraystr]

        n = len(cluster_0_counts)
        print("Number of observations: ", n)
        sns.distplot(cluster_0_counts, bins=35, kde=False, rug=True)
        plt.show()

# %%
sns.set(color_codes=True)
ffile = "../"

# %%
print("Plot cluster 0")
# Out:
# Plot cluster 0

# %%
do_plot(ffile +  "cluster_0_wga_w_mean.txt")
do_plot(ffile +  "cluster_0_no_wga_w_mean.txt")
# Out:
# Number of observations:  45125
# Number of observations:  45125

# %%
print("Plot cluster 1")
# Out:
# Plot cluster 1

# %%
do_plot(ffile +  "cluster_1_wga_w_mean.txt")
do_plot(ffile +  "cluster_1_no_wga_w_mean.txt")
# Out:
# Number of observations:  40301
# Number of observations:  40301

# %%
print("Plot cluster 2")
# Out:
# Plot cluster 2

# %%
#do_plot(ffile +  "cluster_2_wga_w_mean.txt")
#do_plot(ffile +  "cluster_2_no_wga_w_mean.txt")

do_plot(ffile +  "cluster_0_wga_w_mean_gap_N.txt") #"cluster_1_wga_w_mean.txt")
do_plot(ffile +  "cluster_0_no_wga_w_mean_gap_N.txt") #"cluster_1_no_wga_w_mean.txt")
# Out:
# Number of observations:  45125
# Number of observations:  45125

# %%
print("Plot cluster 3")
# Out:
# Plot cluster 3

# %%
#do_plot(ffile +  "cluster_3_wga_w_mean.txt")
#do_plot(ffile +  "cluster_3_no_wga_w_mean.txt")

do_plot(ffile +  "cluster_1_wga_w_mean_gap_N.txt") #"cluster_1_wga_w_mean.txt")
do_plot(ffile +  "cluster_1_no_wga_w_mean_gap_N.txt") #"cluster_1_no_wga_w_mean.txt")
# Out:
# Number of observations:  40301
# Number of observations:  40301

# %%
do_plot(ffile +  "cluster_4_wga_w_mean.txt")
do_plot(ffile +  "cluster_4_no_wga_w_mean.txt")
# Out:
# Number of observations:  17778
# Number of observations:  17778
