# %%
import sys

# %%
sys.path.append("../")

# %%
from helpers import read_configuration_file
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(color_codes=True)
# %matplotlib inline

# %%
# let's plot the clusters and see what we have
def plot_cluster(filename, nbins=35, kde=False, rug=True):

    with open(filename) as file:
        context = file.read()
        size = len(context)
        arraystr= context[1:size-1]
        arraystr = arraystr.split(',')
        cluster_0_counts = [float(item) for item in arraystr]
        sns.distplot(cluster_0_counts, bins=nbins, kde=kde, rug=rug)
        plt.show()

# %% [markdown]
# ## Four Clusters

# %%
ffile = "../../"
tips = ["MANHATAN"]
N_CLUSTERS = 4
cluster_files = []

for i in range(N_CLUSTERS):
    cluster_files.append((ffile + "cluster_" + str(i) + "_wga_w_mean_" + tips[0] +  "_"   + str(N_CLUSTERS) + ".txt",
                          ffile + "cluster_" + str(i) + "_no_wga_w_mean_" + tips[0] + "_" + str(N_CLUSTERS) + ".txt"))

# %%
for i, files in enumerate(cluster_files):
    print("Cluster: ", i)
    plot_cluster(filename=files[0])
    plot_cluster(filename=files[1])
# Out:
# Cluster:  0
# Cluster:  1
# Cluster:  2
# Cluster:  3

# %% [markdown]
# ## Three Clusters

# %%
ffile = "../../"
tips = ["MANHATAN"]
N_CLUSTERS = 3
cluster_files = []

for i in range(N_CLUSTERS):
    cluster_files.append((ffile + "cluster_" + str(i) + "_wga_w_mean_" + tips[0] +  "_"   + str(N_CLUSTERS) + ".txt",
                          ffile + "cluster_" + str(i) + "_no_wga_w_mean_" + tips[0] + "_" + str(N_CLUSTERS) + ".txt"))

# %%
for i, files in enumerate(cluster_files):
    print("Cluster: ", i)
    plot_cluster(filename=files[0])
    plot_cluster(filename=files[1])
# Out:
# Cluster:  0
# Cluster:  1
# Cluster:  2

# %% [markdown]
# ## Two Clusters

# %%
ffile = "../../"
tips = ["MANHATAN"]
N_CLUSTERS = 2
cluster_files = []

for i in range(N_CLUSTERS):
    cluster_files.append((ffile + "cluster_" + str(i) + "_wga_w_mean_" + tips[0] +  "_"   + str(N_CLUSTERS) + ".txt",
                          ffile + "cluster_" + str(i) + "_no_wga_w_mean_" + tips[0] + "_" + str(N_CLUSTERS) + ".txt"))

# %%
for i, files in enumerate(cluster_files):
    print("Cluster: ", i)
    plot_cluster(filename=files[0])
    plot_cluster(filename=files[1])
# Out:
# Cluster:  0
# Cluster:  1

# %% [markdown]
# ## Two Clusters + Ratio feature

# %%
ffile = "../../"
tips = ["MANHATAN"]
N_CLUSTERS = 2
cluster_files = []
cluster_files.append((ffile + "cluster_0_wga_w_mean_MANHATAN_2_MEAN_RATIO.txt",
                          ffile + "cluster_0_no_wga_w_mean_MANHATAN_2_MEAN_RATIO.txt"))
cluster_files.append((ffile + "cluster_1_wga_w_mean_MANHATAN_2_MEAN_RATIO.txt",
                          ffile + "cluster_1_no_wga_w_mean_MANHATAN_2_MEAN_RATIO.txt"))

# %%
for i, files in enumerate(cluster_files):
    print("Cluster: ", i)
    plot_cluster(filename=files[0])
    plot_cluster(filename=files[1])
# Out:
# Cluster:  0
# Cluster:  1

# %% [markdown]
# ## Three clusters + Ratio

# %%
ffile = "../../"
tips = ["MANHATAN"]
N_CLUSTERS = 2
cluster_files = []
cluster_files.append((ffile + "cluster_0_wga_w_mean_MANHATAN_3_MEAN_RATIO.txt",
                          ffile + "cluster_0_no_wga_w_mean_MANHATAN_3_MEAN_RATIO.txt"))
cluster_files.append((ffile + "cluster_1_wga_w_mean_MANHATAN_3_MEAN_RATIO.txt",
                          ffile + "cluster_1_no_wga_w_mean_MANHATAN_3_MEAN_RATIO.txt"))
cluster_files.append((ffile + "cluster_2_wga_w_mean_MANHATAN_3_MEAN_RATIO.txt",
                          ffile + "cluster_2_no_wga_w_mean_MANHATAN_3_MEAN_RATIO.txt"))

# %%
for i, files in enumerate(cluster_files):
    print("Cluster: ", i)
    plot_cluster(filename=files[0], kde=True)
    plot_cluster(filename=files[1])
# Out:
# Cluster:  0
# Cluster:  1
# Cluster:  2

# %% [markdown]
# ### Region Means

# %%
ffile = "../../"
tips = ["MANHATAN"]
N_CLUSTERS = 2
cluster_files = []
cluster_files.append((ffile + "wga_windows_mean_0_MANHATAN_3_MEAN_RATIO.txt",
                          ffile + "no_wga_windows_mean_0_MANHATAN_3_MEAN_RATIO.txt"))

# %%
for i, files in enumerate(cluster_files):
    print("Cluster: ", i)
    plot_cluster(filename=files[0], kde=True)
    plot_cluster(filename=files[1])
# Out:
# Cluster:  0
